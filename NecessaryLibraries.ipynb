# %%
# !pip install json  # standard library
# !pip install pprint
# !pip install requests
# !pip install pandas
# !pip install xml.etree.ElementTree  # standard library
# !pip install pickle
# !pip install numpy
# !pip install os  # standard library
# !pip install matplotlib
# !pip install sklearn
# !pip install os  # standard library
# !pip install sys  # standard library
# !pip install pathlib  # standard library
# !pip install shutil  # standard library
# !pip install azure-storage-blob
# !pip install sql-alchemy
